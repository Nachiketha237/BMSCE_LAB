# %% [markdown]
# Importing and Exporting Data with Pandas

# %%
#importing Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
col_names= ["petal_length_in_cm","petal_width_in_cm","sepal_length_in_cm","sepal_width_in_cm","Class"]

# %%
iris_data = pd.read_csv("/content/iris.data",names=col_names)
iris_data.head()
# Out:
#    petal_length_in_cm  petal_width_in_cm  sepal_length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    sepal_width_in_cm        Class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   petal_length_in_cm  150 non-null    float64
#  1   petal_width_in_cm   150 non-null    float64
#  2   sepal_length_in_cm  150 non-null    float64
#  3   sepal_width_in_cm   150 non-null    float64
#  4   Class               150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.isnull().sum()
# Out:
# petal_length_in_cm    0
# petal_width_in_cm     0
# sepal_length_in_cm    0
# sepal_width_in_cm     0
# Class                 0
# dtype: int64

# %%
iris_data.describe()
# Out:
#        petal_length_in_cm  petal_width_in_cm  sepal_length_in_cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.054000            3.758667
# std              0.828066           0.433594            1.764420
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        sepal_width_in_cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['petal_length_in_cm'].plot(kind='hist', bins=20, title='petal_length_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['petal_width_in_cm'].plot(kind='hist', bins=20, title='petal_width_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['sepal_length_in_cm'].plot(kind='hist', bins=20, title='sepal_length_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['sepal_width_in_cm'].plot(kind='hist', bins=20, title='sepal_width_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='petal_length_in_cm', y='petal_width_in_cm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='petal_width_in_cm', y='sepal_length_in_cm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='sepal_length_in_cm', y='sepal_width_in_cm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['petal_length_in_cm'].plot(kind='line', figsize=(8, 4), title='petal_length_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['petal_width_in_cm'].plot(kind='line', figsize=(8, 4), title='petal_width_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['sepal_length_in_cm'].plot(kind='line', figsize=(8, 4), title='sepal_length_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['sepal_width_in_cm'].plot(kind='line', figsize=(8, 4), title='sepal_width_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data=iris_data.to_numpy()

# %%
dataset=data[:,:-1]

# %%
df = pd.DataFrame(dataset, index=dataset[:,0])

# %%
df.kurt(axis=1)
# Out:
# 5.1   -2.368842
# 4.9   -1.091924
# 4.7   -2.276657
# 4.6    -1.57517
# 5.0   -2.787004
#          ...
# 6.7   -2.983606
# 6.3   -3.790103
# 6.5   -3.127297
# 6.2   -3.387994
# 5.9   -3.345923
# Length: 150, dtype: object

# %%
df.to_csv("cleaned_iris_data.csv")
